# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(128, activation='relu')(input_layer)
second_dense = Dense(units=128, activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units=1, name='y1_output')(second_dense)
third_dense = Dense(units=64, activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units=1, name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │      1,152 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     16,512 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │      8,256 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │        129 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         65 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,114 (102.01 KB)
#  Trainable params: 26,114 (102.01 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 596.3027 - y1_output_loss: 281.8764 - y1_output_root_mean_squared_error: 16.1451 - y2_output_loss: 314.3523 - y2_output_root_mean_squared_error: 17.0613 - val_loss: 41.8906 - val_y1_output_loss: 20.4075 - val_y1_output_root_mean_squared_error: 4.4241 - val_y2_output_loss: 22.5402 - val_y2_output_root_mean_squared_error: 4.7242
# Epoch 2/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.2067 - y1_output_loss: 12.7330 - y1_output_root_mean_squared_error: 3.5628 - y2_output_loss: 17.4692 - y2_output_root_mean_squared_error: 4.1652 - val_loss: 31.3005 - val_y1_output_loss: 13.9313 - val_y1_output_root_mean_squared_error: 3.5596 - val_y2_output_loss: 19.6118 - val_y2_output_root_mean_squared_error: 4.3162
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21.9974 - y1_output_loss: 9.2527 - y1_output_root_mean_squared_error: 3.0352 - y2_output_loss: 12.7477 - y2_output_root_mean_squared_error: 3.5650 - val_loss: 30.1387 - val_y1_output_loss: 10.9779 - val_y1_output_root_mean_squared_error: 3.1953 - val_y2_output_loss: 20.6697 - val_y2_output_root_mean_squared_error: 4.4642
# Epoch 4/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.2431 - y1_output_loss: 8.6114 - y1_output_root_mean_squared_error: 2.9237 - y2_output_loss: 15.6390 - y2_output_root_mean_squared_error: 3.9398 - val_loss: 41.1827 - val_y1_output_loss: 15.1164 - val_y1_output_root_mean_squared_error: 3.8170 - val_y2_output_loss: 26.6771 - val_y2_output_root_mean_squared_error: 5.1588
# Epoch 5/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21.5039 - y1_output_loss: 8.8542 - y1_output_root_mean_squared_error: 2.9736 - y2_output_loss: 12.6491 - y2_output_root_mean_squared_error: 3.5471 - val_loss: 26.4992 - val_y1_output_loss: 11.3054 - val_y1_output_root_mean_squared_error: 3.2594 - val_y2_output_loss: 16.1203 - val_y2_output_root_mean_squared_error: 3.9844
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23.8239 - y1_output_loss: 8.8127 - y1_output_root_mean_squared_error: 2.9666 - y2_output_loss: 15.0146 - y2_output_root_mean_squared_error: 3.8686 - val_loss: 24.5989 - val_y1_output_loss: 9.7638 - val_y1_output_root_mean_squared_error: 3.0606 - val_y2_output_loss: 15.3452 - val_y2_output_root_mean_squared_error: 3.9028
# Epoch 7/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20.4668 - y1_output_loss: 7.6336 - y1_output_root_mean_squared_error: 2.7602 - y2_output_loss: 12.8310 - y2_output_root_mean_squared_error: 3.5755 - val_loss: 26.9719 - val_y1_output_loss: 13.6541 - val_y1_output_root_mean_squared_error: 3.6086 - val_y2_output_loss: 14.2749 - val_y2_output_root_mean_squared_error: 3.7349
# Epoch 8/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23.6284 - y1_output_loss: 9.7075 - y1_output_root_mean_squared_error: 3.1007 - y2_output_loss: 13.9223 - y2_output_root_mean_squared_error: 3.7270 - val_loss: 19.6768 - val_y1_output_loss: 9.1000 - val_y1_output_root_mean_squared_error: 2.9126 - val_y2_output_loss: 11.5889 - val_y2_output_root_mean_squared_error: 3.3457
# Epoch 9/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.9067 - y1_output_loss: 7.3220 - y1_output_root_mean_squared_error: 2.6986 - y2_output_loss: 10.5906 - y2_output_root_mean_squared_error: 3.2467 - val_loss: 54.1048 - val_y1_output_loss: 17.2927 - val_y1_output_root_mean_squared_error: 4.1183 - val_y2_output_loss: 37.1037 - val_y2_output_root_mean_squared_error: 6.0946
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21.1087 - y1_output_loss: 8.2414 - y1_output_root_mean_squared_error: 2.8674 - y2_output_loss: 12.8663 - y2_output_root_mean_squared_error: 3.5752 - val_loss: 18.9226 - val_y1_output_loss: 8.9891 - val_y1_output_root_mean_squared_error: 2.8896 - val_y2_output_loss: 10.9178 - val_y2_output_root_mean_squared_error: 3.2516
# Epoch 11/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18.4218 - y1_output_loss: 7.2851 - y1_output_root_mean_squared_error: 2.6945 - y2_output_loss: 11.1322 - y2_output_root_mean_squared_error: 3.3345 - val_loss: 18.3610 - val_y1_output_loss: 8.7536 - val_y1_output_root_mean_squared_error: 2.8763 - val_y2_output_loss: 10.4338 - val_y2_output_root_mean_squared_error: 3.1762
# Epoch 12/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15.9459 - y1_output_loss: 6.4837 - y1_output_root_mean_squared_error: 2.5453 - y2_output_loss: 9.4602 - y2_output_root_mean_squared_error: 3.0677 - val_loss: 23.9333 - val_y1_output_loss: 10.3835 - val_y1_output_root_mean_squared_error: 3.1149 - val_y2_output_loss: 14.6790 - val_y2_output_root_mean_squared_error: 3.7724
# Epoch 13/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18.6089 - y1_output_loss: 7.7877 - y1_output_root_mean_squared_error: 2.7882 - y2_output_loss: 10.8176 - y2_output_root_mean_squared_error: 3.2814 - val_loss: 19.1600 - val_y1_output_loss: 9.1155 - val_y1_output_root_mean_squared_error: 2.9075 - val_y2_output_loss: 11.1302 - val_y2_output_root_mean_squared_error: 3.2720
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14.6226 - y1_output_loss: 6.0233 - y1_output_root_mean_squared_error: 2.4471 - y2_output_loss: 8.5964 - y2_output_root_mean_squared_error: 2.9267 - val_loss: 21.4684 - val_y1_output_loss: 7.3178 - val_y1_output_root_mean_squared_error: 2.6538 - val_y2_output_loss: 14.6574 - val_y2_output_root_mean_squared_error: 3.7981
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.0880 - y1_output_loss: 6.2938 - y1_output_root_mean_squared_error: 2.4971 - y2_output_loss: 12.7897 - y2_output_root_mean_squared_error: 3.5549 - val_loss: 16.3618 - val_y1_output_loss: 7.9885 - val_y1_output_root_mean_squared_error: 2.7481 - val_y2_output_loss: 9.1450 - val_y2_output_root_mean_squared_error: 2.9681
# Epoch 16/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15.4721 - y1_output_loss: 6.0832 - y1_output_root_mean_squared_error: 2.4565 - y2_output_loss: 9.3869 - y2_output_root_mean_squared_error: 3.0414 - val_loss: 14.2375 - val_y1_output_loss: 6.5718 - val_y1_output_root_mean_squared_error: 2.4955 - val_y2_output_loss: 8.3085 - val_y2_output_root_mean_squared_error: 2.8302
# Epoch 17/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14.4816 - y1_output_loss: 5.5689 - y1_output_root_mean_squared_error: 2.3550 - y2_output_loss: 8.9093 - y2_output_root_mean_squared_error: 2.9760 - val_loss: 13.8157 - val_y1_output_loss: 6.1934 - val_y1_output_root_mean_squared_error: 2.4408 - val_y2_output_loss: 8.0306 - val_y2_output_root_mean_squared_error: 2.8033
# Epoch 18/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.5184 - y1_output_loss: 5.0752 - y1_output_root_mean_squared_error: 2.2507 - y2_output_loss: 8.4410 - y2_output_root_mean_squared_error: 2.8855 - val_loss: 19.8508 - val_y1_output_loss: 8.9168 - val_y1_output_root_mean_squared_error: 2.9045 - val_y2_output_loss: 11.9410 - val_y2_output_root_mean_squared_error: 3.3785
# Epoch 19/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.0580 - y1_output_loss: 4.3680 - y1_output_root_mean_squared_error: 2.0837 - y2_output_loss: 6.6872 - y2_output_root_mean_squared_error: 2.5472 - val_loss: 13.9677 - val_y1_output_loss: 6.7307 - val_y1_output_root_mean_squared_error: 2.5382 - val_y2_output_loss: 7.8184 - val_y2_output_root_mean_squared_error: 2.7432
# Epoch 20/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.5578 - y1_output_loss: 5.6771 - y1_output_root_mean_squared_error: 2.3695 - y2_output_loss: 6.8786 - y2_output_root_mean_squared_error: 2.6211 - val_loss: 19.5672 - val_y1_output_loss: 7.9841 - val_y1_output_root_mean_squared_error: 2.7544 - val_y2_output_loss: 12.4705 - val_y2_output_root_mean_squared_error: 3.4613
# Epoch 21/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.7118 - y1_output_loss: 4.3785 - y1_output_root_mean_squared_error: 2.0892 - y2_output_loss: 9.3310 - y2_output_root_mean_squared_error: 3.0383 - val_loss: 24.5566 - val_y1_output_loss: 7.3470 - val_y1_output_root_mean_squared_error: 2.6880 - val_y2_output_loss: 17.6010 - val_y2_output_root_mean_squared_error: 4.1631
# Epoch 22/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.8324 - y1_output_loss: 4.8970 - y1_output_root_mean_squared_error: 2.2059 - y2_output_loss: 6.9330 - y2_output_root_mean_squared_error: 2.6292 - val_loss: 12.6103 - val_y1_output_loss: 5.5139 - val_y1_output_root_mean_squared_error: 2.2938 - val_y2_output_loss: 7.5775 - val_y2_output_root_mean_squared_error: 2.7109
# Epoch 23/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.7694 - y1_output_loss: 3.8136 - y1_output_root_mean_squared_error: 1.9488 - y2_output_loss: 6.9645 - y2_output_root_mean_squared_error: 2.6324 - val_loss: 30.6013 - val_y1_output_loss: 9.0806 - val_y1_output_root_mean_squared_error: 2.9722 - val_y2_output_loss: 21.9539 - val_y2_output_root_mean_squared_error: 4.6656
# Epoch 24/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.5325 - y1_output_loss: 4.2628 - y1_output_root_mean_squared_error: 2.0617 - y2_output_loss: 7.2681 - y2_output_root_mean_squared_error: 2.6918 - val_loss: 14.3880 - val_y1_output_loss: 5.6506 - val_y1_output_root_mean_squared_error: 2.3305 - val_y2_output_loss: 9.2285 - val_y2_output_root_mean_squared_error: 2.9928
# Epoch 25/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.2026 - y1_output_loss: 3.8772 - y1_output_root_mean_squared_error: 1.9617 - y2_output_loss: 6.3511 - y2_output_root_mean_squared_error: 2.4994 - val_loss: 13.5751 - val_y1_output_loss: 5.0255 - val_y1_output_root_mean_squared_error: 2.2209 - val_y2_output_loss: 8.7997 - val_y2_output_root_mean_squared_error: 2.9398
# Epoch 26/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6188 - y1_output_loss: 3.6500 - y1_output_root_mean_squared_error: 1.9055 - y2_output_loss: 5.9742 - y2_output_root_mean_squared_error: 2.4408 - val_loss: 22.8972 - val_y1_output_loss: 7.9229 - val_y1_output_root_mean_squared_error: 2.8052 - val_y2_output_loss: 15.0962 - val_y2_output_root_mean_squared_error: 3.8766
# Epoch 27/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.3628 - y1_output_loss: 5.3229 - y1_output_root_mean_squared_error: 2.2675 - y2_output_loss: 8.0507 - y2_output_root_mean_squared_error: 2.8009 - val_loss: 60.7966 - val_y1_output_loss: 12.4975 - val_y1_output_root_mean_squared_error: 3.5156 - val_y2_output_loss: 49.3860 - val_y2_output_root_mean_squared_error: 6.9597
# Epoch 28/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.0450 - y1_output_loss: 4.2143 - y1_output_root_mean_squared_error: 2.0511 - y2_output_loss: 8.8304 - y2_output_root_mean_squared_error: 2.9419 - val_loss: 10.5933 - val_y1_output_loss: 4.1160 - val_y1_output_root_mean_squared_error: 1.9961 - val_y2_output_loss: 6.7716 - val_y2_output_root_mean_squared_error: 2.5708
# Epoch 29/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5911 - y1_output_loss: 3.2101 - y1_output_root_mean_squared_error: 1.7873 - y2_output_loss: 6.3785 - y2_output_root_mean_squared_error: 2.5236 - val_loss: 11.6126 - val_y1_output_loss: 4.9114 - val_y1_output_root_mean_squared_error: 2.2014 - val_y2_output_loss: 6.9830 - val_y2_output_root_mean_squared_error: 2.6013
# Epoch 30/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3658 - y1_output_loss: 3.4400 - y1_output_root_mean_squared_error: 1.8518 - y2_output_loss: 5.9250 - y2_output_root_mean_squared_error: 2.4323 - val_loss: 11.4997 - val_y1_output_loss: 4.4864 - val_y1_output_root_mean_squared_error: 2.0785 - val_y2_output_loss: 7.4832 - val_y2_output_root_mean_squared_error: 2.6795
# Epoch 31/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.3539 - y1_output_loss: 4.3145 - y1_output_root_mean_squared_error: 2.0703 - y2_output_loss: 9.0394 - y2_output_root_mean_squared_error: 2.9776 - val_loss: 24.1758 - val_y1_output_loss: 7.6628 - val_y1_output_root_mean_squared_error: 2.7251 - val_y2_output_loss: 17.3807 - val_y2_output_root_mean_squared_error: 4.0926
# Epoch 32/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.7152 - y1_output_loss: 3.3044 - y1_output_root_mean_squared_error: 1.8089 - y2_output_loss: 7.4118 - y2_output_root_mean_squared_error: 2.7177 - val_loss: 18.6402 - val_y1_output_loss: 7.5991 - val_y1_output_root_mean_squared_error: 2.7752 - val_y2_output_loss: 10.8193 - val_y2_output_root_mean_squared_error: 3.3074
# Epoch 33/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1041 - y1_output_loss: 2.9120 - y1_output_root_mean_squared_error: 1.7013 - y2_output_loss: 6.1907 - y2_output_root_mean_squared_error: 2.4805 - val_loss: 14.4264 - val_y1_output_loss: 4.7621 - val_y1_output_root_mean_squared_error: 2.1405 - val_y2_output_loss: 10.3085 - val_y2_output_root_mean_squared_error: 3.1376
# Epoch 34/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1323 - y1_output_loss: 2.9117 - y1_output_root_mean_squared_error: 1.7039 - y2_output_loss: 5.2182 - y2_output_root_mean_squared_error: 2.2784 - val_loss: 8.7710 - val_y1_output_loss: 3.7445 - val_y1_output_root_mean_squared_error: 1.8820 - val_y2_output_loss: 5.5837 - val_y2_output_root_mean_squared_error: 2.2867
# Epoch 35/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4754 - y1_output_loss: 2.7571 - y1_output_root_mean_squared_error: 1.6487 - y2_output_loss: 4.7187 - y2_output_root_mean_squared_error: 2.1649 - val_loss: 8.1218 - val_y1_output_loss: 3.3558 - val_y1_output_root_mean_squared_error: 1.7960 - val_y2_output_loss: 5.2406 - val_y2_output_root_mean_squared_error: 2.2127
# Epoch 36/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8874 - y1_output_loss: 2.8931 - y1_output_root_mean_squared_error: 1.6973 - y2_output_loss: 4.9950 - y2_output_root_mean_squared_error: 2.2264 - val_loss: 12.5120 - val_y1_output_loss: 4.7717 - val_y1_output_root_mean_squared_error: 2.1906 - val_y2_output_loss: 7.8476 - val_y2_output_root_mean_squared_error: 2.7772
# Epoch 37/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7267 - y1_output_loss: 2.6068 - y1_output_root_mean_squared_error: 1.6099 - y2_output_loss: 5.1214 - y2_output_root_mean_squared_error: 2.2599 - val_loss: 18.8533 - val_y1_output_loss: 3.9368 - val_y1_output_root_mean_squared_error: 1.9455 - val_y2_output_loss: 15.2704 - val_y2_output_root_mean_squared_error: 3.8818
# Epoch 38/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3009 - y1_output_loss: 2.3557 - y1_output_root_mean_squared_error: 1.5319 - y2_output_loss: 5.9478 - y2_output_root_mean_squared_error: 2.4224 - val_loss: 37.7890 - val_y1_output_loss: 12.9860 - val_y1_output_root_mean_squared_error: 3.5949 - val_y2_output_loss: 25.4280 - val_y2_output_root_mean_squared_error: 4.9866
# Epoch 39/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.1377 - y1_output_loss: 3.9436 - y1_output_root_mean_squared_error: 1.9679 - y2_output_loss: 7.1915 - y2_output_root_mean_squared_error: 2.6767 - val_loss: 8.3770 - val_y1_output_loss: 2.9058 - val_y1_output_root_mean_squared_error: 1.6893 - val_y2_output_loss: 5.6860 - val_y2_output_root_mean_squared_error: 2.3502
# Epoch 40/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.3337 - y1_output_loss: 3.7836 - y1_output_root_mean_squared_error: 1.9334 - y2_output_loss: 6.5509 - y2_output_root_mean_squared_error: 2.5509 - val_loss: 17.9712 - val_y1_output_loss: 6.2453 - val_y1_output_root_mean_squared_error: 2.4599 - val_y2_output_loss: 12.0652 - val_y2_output_root_mean_squared_error: 3.4525
# Epoch 41/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9788 - y1_output_loss: 2.4357 - y1_output_root_mean_squared_error: 1.5553 - y2_output_loss: 4.5437 - y2_output_root_mean_squared_error: 2.1285 - val_loss: 10.3823 - val_y1_output_loss: 4.6395 - val_y1_output_root_mean_squared_error: 2.1522 - val_y2_output_loss: 6.0829 - val_y2_output_root_mean_squared_error: 2.3980
# Epoch 42/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1911 - y1_output_loss: 2.4039 - y1_output_root_mean_squared_error: 1.5447 - y2_output_loss: 5.7910 - y2_output_root_mean_squared_error: 2.3733 - val_loss: 20.8913 - val_y1_output_loss: 6.6660 - val_y1_output_root_mean_squared_error: 2.5859 - val_y2_output_loss: 14.1145 - val_y2_output_root_mean_squared_error: 3.7689
# Epoch 43/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2005 - y1_output_loss: 3.2826 - y1_output_root_mean_squared_error: 1.7922 - y2_output_loss: 5.9165 - y2_output_root_mean_squared_error: 2.4149 - val_loss: 7.6134 - val_y1_output_loss: 3.0112 - val_y1_output_root_mean_squared_error: 1.7316 - val_y2_output_loss: 4.8647 - val_y2_output_root_mean_squared_error: 2.1482
# Epoch 44/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0540 - y1_output_loss: 2.4306 - y1_output_root_mean_squared_error: 1.5581 - y2_output_loss: 4.6214 - y2_output_root_mean_squared_error: 2.1473 - val_loss: 6.6875 - val_y1_output_loss: 2.5934 - val_y1_output_root_mean_squared_error: 1.6130 - val_y2_output_loss: 4.3865 - val_y2_output_root_mean_squared_error: 2.0213
# Epoch 45/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5274 - y1_output_loss: 2.0805 - y1_output_root_mean_squared_error: 1.4398 - y2_output_loss: 4.4509 - y2_output_root_mean_squared_error: 2.1028 - val_loss: 54.2322 - val_y1_output_loss: 9.0328 - val_y1_output_root_mean_squared_error: 2.9990 - val_y2_output_loss: 46.4486 - val_y2_output_root_mean_squared_error: 6.7259
# Epoch 46/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2267 - y1_output_loss: 2.3495 - y1_output_root_mean_squared_error: 1.5292 - y2_output_loss: 4.8773 - y2_output_root_mean_squared_error: 2.1847 - val_loss: 8.2352 - val_y1_output_loss: 3.4568 - val_y1_output_root_mean_squared_error: 1.8369 - val_y2_output_loss: 5.0966 - val_y2_output_root_mean_squared_error: 2.2048
# Epoch 47/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9534 - y1_output_loss: 2.0238 - y1_output_root_mean_squared_error: 1.4209 - y2_output_loss: 4.9278 - y2_output_root_mean_squared_error: 2.2159 - val_loss: 12.3276 - val_y1_output_loss: 3.7582 - val_y1_output_root_mean_squared_error: 1.9462 - val_y2_output_loss: 8.8474 - val_y2_output_root_mean_squared_error: 2.9223
# Epoch 48/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8278 - y1_output_loss: 2.4542 - y1_output_root_mean_squared_error: 1.5597 - y2_output_loss: 5.3730 - y2_output_root_mean_squared_error: 2.3062 - val_loss: 9.3246 - val_y1_output_loss: 3.2143 - val_y1_output_root_mean_squared_error: 1.7766 - val_y2_output_loss: 6.3499 - val_y2_output_root_mean_squared_error: 2.4836
# Epoch 49/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6102 - y1_output_loss: 2.5231 - y1_output_root_mean_squared_error: 1.5846 - y2_output_loss: 4.0855 - y2_output_root_mean_squared_error: 2.0157 - val_loss: 6.6912 - val_y1_output_loss: 2.5036 - val_y1_output_root_mean_squared_error: 1.5797 - val_y2_output_loss: 4.4014 - val_y2_output_root_mean_squared_error: 2.0484
# Epoch 50/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9450 - y1_output_loss: 1.7517 - y1_output_root_mean_squared_error: 1.3204 - y2_output_loss: 4.1915 - y2_output_root_mean_squared_error: 2.0461 - val_loss: 11.6744 - val_y1_output_loss: 4.2566 - val_y1_output_root_mean_squared_error: 2.0799 - val_y2_output_loss: 7.6557 - val_y2_output_root_mean_squared_error: 2.7108
# Epoch 51/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4678 - y1_output_loss: 2.7621 - y1_output_root_mean_squared_error: 1.6527 - y2_output_loss: 6.7051 - y2_output_root_mean_squared_error: 2.5821 - val_loss: 16.1951 - val_y1_output_loss: 6.4378 - val_y1_output_root_mean_squared_error: 2.5630 - val_y2_output_loss: 9.8712 - val_y2_output_root_mean_squared_error: 3.1026
# Epoch 52/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2980 - y1_output_loss: 2.3692 - y1_output_root_mean_squared_error: 1.5354 - y2_output_loss: 6.9281 - y2_output_root_mean_squared_error: 2.6231 - val_loss: 10.8580 - val_y1_output_loss: 5.0106 - val_y1_output_root_mean_squared_error: 2.2367 - val_y2_output_loss: 6.1297 - val_y2_output_root_mean_squared_error: 2.4197
# Epoch 53/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5888 - y1_output_loss: 2.2720 - y1_output_root_mean_squared_error: 1.5012 - y2_output_loss: 5.3147 - y2_output_root_mean_squared_error: 2.2928 - val_loss: 6.7694 - val_y1_output_loss: 2.5384 - val_y1_output_root_mean_squared_error: 1.5762 - val_y2_output_loss: 4.6260 - val_y2_output_root_mean_squared_error: 2.0700
# Epoch 54/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.8334 - y1_output_loss: 1.6222 - y1_output_root_mean_squared_error: 1.2724 - y2_output_loss: 4.2100 - y2_output_root_mean_squared_error: 2.0482 - val_loss: 6.2008 - val_y1_output_loss: 2.1384 - val_y1_output_root_mean_squared_error: 1.4346 - val_y2_output_loss: 4.4161 - val_y2_output_root_mean_squared_error: 2.0354
# Epoch 55/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6767 - y1_output_loss: 1.7236 - y1_output_root_mean_squared_error: 1.3113 - y2_output_loss: 3.9523 - y2_output_root_mean_squared_error: 1.9788 - val_loss: 6.0879 - val_y1_output_loss: 2.2255 - val_y1_output_root_mean_squared_error: 1.4816 - val_y2_output_loss: 4.0964 - val_y2_output_root_mean_squared_error: 1.9730
# Epoch 56/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9240 - y1_output_loss: 1.7647 - y1_output_root_mean_squared_error: 1.3255 - y2_output_loss: 5.1607 - y2_output_root_mean_squared_error: 2.2694 - val_loss: 22.0231 - val_y1_output_loss: 3.6938 - val_y1_output_root_mean_squared_error: 1.9299 - val_y2_output_loss: 18.6610 - val_y2_output_root_mean_squared_error: 4.2777
# Epoch 57/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9732 - y1_output_loss: 2.0027 - y1_output_root_mean_squared_error: 1.4136 - y2_output_loss: 4.9696 - y2_output_root_mean_squared_error: 2.2170 - val_loss: 5.7252 - val_y1_output_loss: 2.2672 - val_y1_output_root_mean_squared_error: 1.5078 - val_y2_output_loss: 3.6605 - val_y2_output_root_mean_squared_error: 1.8579
# Epoch 58/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.3802 - y1_output_loss: 1.6919 - y1_output_root_mean_squared_error: 1.2926 - y2_output_loss: 5.6878 - y2_output_root_mean_squared_error: 2.3414 - val_loss: 5.6861 - val_y1_output_loss: 1.8132 - val_y1_output_root_mean_squared_error: 1.3419 - val_y2_output_loss: 4.0887 - val_y2_output_root_mean_squared_error: 1.9711
# Epoch 59/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8199 - y1_output_loss: 1.4732 - y1_output_root_mean_squared_error: 1.2125 - y2_output_loss: 3.3465 - y2_output_root_mean_squared_error: 1.8255 - val_loss: 5.3012 - val_y1_output_loss: 1.7422 - val_y1_output_root_mean_squared_error: 1.3184 - val_y2_output_loss: 3.7357 - val_y2_output_root_mean_squared_error: 1.8876
# Epoch 60/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3319 - y1_output_loss: 1.4380 - y1_output_root_mean_squared_error: 1.1948 - y2_output_loss: 4.8963 - y2_output_root_mean_squared_error: 2.1909 - val_loss: 6.4214 - val_y1_output_loss: 1.7990 - val_y1_output_root_mean_squared_error: 1.3349 - val_y2_output_loss: 4.8954 - val_y2_output_root_mean_squared_error: 2.1539
# Epoch 61/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8673 - y1_output_loss: 2.0800 - y1_output_root_mean_squared_error: 1.4119 - y2_output_loss: 4.7850 - y2_output_root_mean_squared_error: 2.1392 - val_loss: 11.9082 - val_y1_output_loss: 3.5662 - val_y1_output_root_mean_squared_error: 1.8652 - val_y2_output_loss: 8.5796 - val_y2_output_root_mean_squared_error: 2.9033
# Epoch 62/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6896 - y1_output_loss: 1.4498 - y1_output_root_mean_squared_error: 1.2000 - y2_output_loss: 4.2384 - y2_output_root_mean_squared_error: 2.0502 - val_loss: 5.0542 - val_y1_output_loss: 1.9996 - val_y1_output_root_mean_squared_error: 1.4002 - val_y2_output_loss: 3.3477 - val_y2_output_root_mean_squared_error: 1.7589
# Epoch 63/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4985 - y1_output_loss: 1.4262 - y1_output_root_mean_squared_error: 1.1921 - y2_output_loss: 4.0718 - y2_output_root_mean_squared_error: 2.0140 - val_loss: 6.7673 - val_y1_output_loss: 1.5161 - val_y1_output_root_mean_squared_error: 1.2454 - val_y2_output_loss: 5.4889 - val_y2_output_root_mean_squared_error: 2.2839
# Epoch 64/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0496 - y1_output_loss: 1.3611 - y1_output_root_mean_squared_error: 1.1617 - y2_output_loss: 3.6893 - y2_output_root_mean_squared_error: 1.9159 - val_loss: 5.8062 - val_y1_output_loss: 1.9230 - val_y1_output_root_mean_squared_error: 1.4045 - val_y2_output_loss: 4.0064 - val_y2_output_root_mean_squared_error: 1.9580
# Epoch 65/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8442 - y1_output_loss: 1.1131 - y1_output_root_mean_squared_error: 1.0533 - y2_output_loss: 2.7309 - y2_output_root_mean_squared_error: 1.6504 - val_loss: 5.8984 - val_y1_output_loss: 1.9857 - val_y1_output_root_mean_squared_error: 1.4223 - val_y2_output_loss: 4.0359 - val_y2_output_root_mean_squared_error: 1.9686
# Epoch 66/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0005 - y1_output_loss: 1.1379 - y1_output_root_mean_squared_error: 1.0650 - y2_output_loss: 2.8647 - y2_output_root_mean_squared_error: 1.6866 - val_loss: 11.7652 - val_y1_output_loss: 2.1818 - val_y1_output_root_mean_squared_error: 1.4996 - val_y2_output_loss: 9.7849 - val_y2_output_root_mean_squared_error: 3.0849
# Epoch 67/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3984 - y1_output_loss: 1.4245 - y1_output_root_mean_squared_error: 1.1862 - y2_output_loss: 3.9733 - y2_output_root_mean_squared_error: 1.9796 - val_loss: 7.3353 - val_y1_output_loss: 3.6978 - val_y1_output_root_mean_squared_error: 1.9457 - val_y2_output_loss: 3.6670 - val_y2_output_root_mean_squared_error: 1.8841
# Epoch 68/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3642 - y1_output_loss: 1.6154 - y1_output_root_mean_squared_error: 1.2399 - y2_output_loss: 4.7500 - y2_output_root_mean_squared_error: 2.1444 - val_loss: 21.1516 - val_y1_output_loss: 5.9889 - val_y1_output_root_mean_squared_error: 2.4346 - val_y2_output_loss: 15.2708 - val_y2_output_root_mean_squared_error: 3.9018
# Epoch 69/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25.4937 - y1_output_loss: 8.6513 - y1_output_root_mean_squared_error: 2.7625 - y2_output_loss: 16.8416 - y2_output_root_mean_squared_error: 3.8992 - val_loss: 12.7947 - val_y1_output_loss: 3.6899 - val_y1_output_root_mean_squared_error: 1.9097 - val_y2_output_loss: 9.2505 - val_y2_output_root_mean_squared_error: 3.0245
# Epoch 70/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6921 - y1_output_loss: 1.3088 - y1_output_root_mean_squared_error: 1.1345 - y2_output_loss: 4.3842 - y2_output_root_mean_squared_error: 2.0752 - val_loss: 6.1810 - val_y1_output_loss: 1.9550 - val_y1_output_root_mean_squared_error: 1.4123 - val_y2_output_loss: 4.2978 - val_y2_output_root_mean_squared_error: 2.0461
# Epoch 71/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4313 - y1_output_loss: 1.0717 - y1_output_root_mean_squared_error: 1.0286 - y2_output_loss: 3.3584 - y2_output_root_mean_squared_error: 1.8295 - val_loss: 4.4393 - val_y1_output_loss: 1.4557 - val_y1_output_root_mean_squared_error: 1.2136 - val_y2_output_loss: 3.1078 - val_y2_output_root_mean_squared_error: 1.7224
# Epoch 72/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6318 - y1_output_loss: 0.9155 - y1_output_root_mean_squared_error: 0.9488 - y2_output_loss: 2.7158 - y2_output_root_mean_squared_error: 1.6414 - val_loss: 4.9321 - val_y1_output_loss: 1.8163 - val_y1_output_root_mean_squared_error: 1.3511 - val_y2_output_loss: 3.3075 - val_y2_output_root_mean_squared_error: 1.7625
# Epoch 73/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9502 - y1_output_loss: 1.1479 - y1_output_root_mean_squared_error: 1.0688 - y2_output_loss: 3.8017 - y2_output_root_mean_squared_error: 1.9455 - val_loss: 6.6203 - val_y1_output_loss: 1.5686 - val_y1_output_root_mean_squared_error: 1.2456 - val_y2_output_loss: 5.1797 - val_y2_output_root_mean_squared_error: 2.2514
# Epoch 74/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0548 - y1_output_loss: 1.4925 - y1_output_root_mean_squared_error: 1.2181 - y2_output_loss: 4.5624 - y2_output_root_mean_squared_error: 2.1300 - val_loss: 6.3767 - val_y1_output_loss: 1.5494 - val_y1_output_root_mean_squared_error: 1.2587 - val_y2_output_loss: 4.9699 - val_y2_output_root_mean_squared_error: 2.1892
# Epoch 75/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4322 - y1_output_loss: 1.1007 - y1_output_root_mean_squared_error: 1.0429 - y2_output_loss: 3.3329 - y2_output_root_mean_squared_error: 1.8107 - val_loss: 6.7618 - val_y1_output_loss: 1.4171 - val_y1_output_root_mean_squared_error: 1.1830 - val_y2_output_loss: 5.4366 - val_y2_output_root_mean_squared_error: 2.3157
# Epoch 76/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4468 - y1_output_loss: 0.8313 - y1_output_root_mean_squared_error: 0.9102 - y2_output_loss: 2.6161 - y2_output_root_mean_squared_error: 1.6134 - val_loss: 4.7174 - val_y1_output_loss: 1.4048 - val_y1_output_root_mean_squared_error: 1.2017 - val_y2_output_loss: 3.3666 - val_y2_output_root_mean_squared_error: 1.8093
# Epoch 77/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9293 - y1_output_loss: 1.3625 - y1_output_root_mean_squared_error: 1.1622 - y2_output_loss: 4.5650 - y2_output_root_mean_squared_error: 2.1287 - val_loss: 4.0616 - val_y1_output_loss: 1.3364 - val_y1_output_root_mean_squared_error: 1.1495 - val_y2_output_loss: 2.8280 - val_y2_output_root_mean_squared_error: 1.6554
# Epoch 78/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5423 - y1_output_loss: 1.0357 - y1_output_root_mean_squared_error: 1.0166 - y2_output_loss: 2.5091 - y2_output_root_mean_squared_error: 1.5790 - val_loss: 12.4994 - val_y1_output_loss: 1.7899 - val_y1_output_root_mean_squared_error: 1.3139 - val_y2_output_loss: 10.9165 - val_y2_output_root_mean_squared_error: 3.2823
# Epoch 79/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9885 - y1_output_loss: 1.3353 - y1_output_root_mean_squared_error: 1.1510 - y2_output_loss: 3.6521 - y2_output_root_mean_squared_error: 1.8948 - val_loss: 3.2709 - val_y1_output_loss: 0.8695 - val_y1_output_root_mean_squared_error: 0.9401 - val_y2_output_loss: 2.4874 - val_y2_output_root_mean_squared_error: 1.5450
# Epoch 80/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9320 - y1_output_loss: 0.9533 - y1_output_root_mean_squared_error: 0.9674 - y2_output_loss: 3.9793 - y2_output_root_mean_squared_error: 1.9744 - val_loss: 6.1757 - val_y1_output_loss: 1.0119 - val_y1_output_root_mean_squared_error: 1.0230 - val_y2_output_loss: 5.1925 - val_y2_output_root_mean_squared_error: 2.2648
# Epoch 81/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6657 - y1_output_loss: 2.1130 - y1_output_root_mean_squared_error: 1.4280 - y2_output_loss: 5.5520 - y2_output_root_mean_squared_error: 2.3098 - val_loss: 8.5731 - val_y1_output_loss: 2.3746 - val_y1_output_root_mean_squared_error: 1.5355 - val_y2_output_loss: 6.3131 - val_y2_output_root_mean_squared_error: 2.4931
# Epoch 82/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3031 - y1_output_loss: 1.3794 - y1_output_root_mean_squared_error: 1.1672 - y2_output_loss: 3.9242 - y2_output_root_mean_squared_error: 1.9741 - val_loss: 8.8506 - val_y1_output_loss: 1.6411 - val_y1_output_root_mean_squared_error: 1.2936 - val_y2_output_loss: 7.3443 - val_y2_output_root_mean_squared_error: 2.6790
# Epoch 83/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6684 - y1_output_loss: 0.8018 - y1_output_root_mean_squared_error: 0.8905 - y2_output_loss: 2.8696 - y2_output_root_mean_squared_error: 1.6683 - val_loss: 29.3981 - val_y1_output_loss: 3.3797 - val_y1_output_root_mean_squared_error: 1.8552 - val_y2_output_loss: 26.3826 - val_y2_output_root_mean_squared_error: 5.0947
# Epoch 84/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5946 - y1_output_loss: 0.8814 - y1_output_root_mean_squared_error: 0.9327 - y2_output_loss: 4.7138 - y2_output_root_mean_squared_error: 2.1141 - val_loss: 6.8339 - val_y1_output_loss: 2.6592 - val_y1_output_root_mean_squared_error: 1.6307 - val_y2_output_loss: 4.2765 - val_y2_output_root_mean_squared_error: 2.0432
# Epoch 85/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9703 - y1_output_loss: 0.7950 - y1_output_root_mean_squared_error: 0.8903 - y2_output_loss: 2.1753 - y2_output_root_mean_squared_error: 1.4721 - val_loss: 6.0879 - val_y1_output_loss: 0.8672 - val_y1_output_root_mean_squared_error: 0.9409 - val_y2_output_loss: 5.3147 - val_y2_output_root_mean_squared_error: 2.2809
# Epoch 86/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7847 - y1_output_loss: 1.3654 - y1_output_root_mean_squared_error: 1.1647 - y2_output_loss: 3.4181 - y2_output_root_mean_squared_error: 1.8420 - val_loss: 3.5210 - val_y1_output_loss: 1.0601 - val_y1_output_root_mean_squared_error: 1.0420 - val_y2_output_loss: 2.5111 - val_y2_output_root_mean_squared_error: 1.5605
# Epoch 87/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3001 - y1_output_loss: 0.7724 - y1_output_root_mean_squared_error: 0.8759 - y2_output_loss: 2.5275 - y2_output_root_mean_squared_error: 1.5851 - val_loss: 3.4789 - val_y1_output_loss: 0.9943 - val_y1_output_root_mean_squared_error: 0.9975 - val_y2_output_loss: 2.5778 - val_y2_output_root_mean_squared_error: 1.5760
# Epoch 88/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8375 - y1_output_loss: 0.7284 - y1_output_root_mean_squared_error: 0.8517 - y2_output_loss: 2.1092 - y2_output_root_mean_squared_error: 1.4500 - val_loss: 5.6602 - val_y1_output_loss: 0.9336 - val_y1_output_root_mean_squared_error: 0.9818 - val_y2_output_loss: 4.8451 - val_y2_output_root_mean_squared_error: 2.1671
# Epoch 89/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8231 - y1_output_loss: 0.7348 - y1_output_root_mean_squared_error: 0.8494 - y2_output_loss: 2.0875 - y2_output_root_mean_squared_error: 1.4372 - val_loss: 3.4824 - val_y1_output_loss: 1.0183 - val_y1_output_root_mean_squared_error: 1.0242 - val_y2_output_loss: 2.5161 - val_y2_output_root_mean_squared_error: 1.5600
# Epoch 90/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6330 - y1_output_loss: 0.5592 - y1_output_root_mean_squared_error: 0.7470 - y2_output_loss: 2.0743 - y2_output_root_mean_squared_error: 1.4381 - val_loss: 6.1119 - val_y1_output_loss: 2.2129 - val_y1_output_root_mean_squared_error: 1.4923 - val_y2_output_loss: 4.0024 - val_y2_output_root_mean_squared_error: 1.9710
# Epoch 91/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1521 - y1_output_loss: 0.8517 - y1_output_root_mean_squared_error: 0.9051 - y2_output_loss: 2.2995 - y2_output_root_mean_squared_error: 1.5117 - val_loss: 3.8366 - val_y1_output_loss: 0.9039 - val_y1_output_root_mean_squared_error: 0.9443 - val_y2_output_loss: 2.9991 - val_y2_output_root_mean_squared_error: 1.7161
# Epoch 92/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4223 - y1_output_loss: 1.0592 - y1_output_root_mean_squared_error: 1.0106 - y2_output_loss: 4.3625 - y2_output_root_mean_squared_error: 2.0422 - val_loss: 3.3387 - val_y1_output_loss: 0.8393 - val_y1_output_root_mean_squared_error: 0.9159 - val_y2_output_loss: 2.5643 - val_y2_output_root_mean_squared_error: 1.5811
# Epoch 93/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4208 - y1_output_loss: 0.4603 - y1_output_root_mean_squared_error: 0.6758 - y2_output_loss: 1.9603 - y2_output_root_mean_squared_error: 1.3967 - val_loss: 3.2559 - val_y1_output_loss: 0.7694 - val_y1_output_root_mean_squared_error: 0.8670 - val_y2_output_loss: 2.5796 - val_y2_output_root_mean_squared_error: 1.5825
# Epoch 94/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1078 - y1_output_loss: 0.5928 - y1_output_root_mean_squared_error: 0.7664 - y2_output_loss: 2.5190 - y2_output_root_mean_squared_error: 1.5838 - val_loss: 8.4972 - val_y1_output_loss: 1.3583 - val_y1_output_root_mean_squared_error: 1.1677 - val_y2_output_loss: 7.1421 - val_y2_output_root_mean_squared_error: 2.6709
# Epoch 95/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7775 - y1_output_loss: 0.6391 - y1_output_root_mean_squared_error: 0.7969 - y2_output_loss: 2.1384 - y2_output_root_mean_squared_error: 1.4595 - val_loss: 3.8820 - val_y1_output_loss: 0.7379 - val_y1_output_root_mean_squared_error: 0.8629 - val_y2_output_loss: 3.1891 - val_y2_output_root_mean_squared_error: 1.7713
# Epoch 96/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0650 - y1_output_loss: 0.7252 - y1_output_root_mean_squared_error: 0.8489 - y2_output_loss: 2.3397 - y2_output_root_mean_squared_error: 1.5242 - val_loss: 3.4622 - val_y1_output_loss: 0.8499 - val_y1_output_root_mean_squared_error: 0.9355 - val_y2_output_loss: 2.7081 - val_y2_output_root_mean_squared_error: 1.6084
# Epoch 97/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8448 - y1_output_loss: 0.7162 - y1_output_root_mean_squared_error: 0.8429 - y2_output_loss: 2.1279 - y2_output_root_mean_squared_error: 1.4544 - val_loss: 2.5905 - val_y1_output_loss: 0.7119 - val_y1_output_root_mean_squared_error: 0.8416 - val_y2_output_loss: 1.9144 - val_y2_output_root_mean_squared_error: 1.3720
# Epoch 98/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4498 - y1_output_loss: 0.6598 - y1_output_root_mean_squared_error: 0.8098 - y2_output_loss: 1.7894 - y2_output_root_mean_squared_error: 1.3174 - val_loss: 2.5776 - val_y1_output_loss: 0.7718 - val_y1_output_root_mean_squared_error: 0.8873 - val_y2_output_loss: 1.8551 - val_y2_output_root_mean_squared_error: 1.3380
# Epoch 99/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3130 - y1_output_loss: 0.5542 - y1_output_root_mean_squared_error: 0.7428 - y2_output_loss: 1.7586 - y2_output_root_mean_squared_error: 1.3245 - val_loss: 4.3369 - val_y1_output_loss: 1.5171 - val_y1_output_root_mean_squared_error: 1.2507 - val_y2_output_loss: 2.8499 - val_y2_output_root_mean_squared_error: 1.6651
# Epoch 100/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1645 - y1_output_loss: 0.7786 - y1_output_root_mean_squared_error: 0.8808 - y2_output_loss: 2.3853 - y2_output_root_mean_squared_error: 1.5436 - val_loss: 3.7545 - val_y1_output_loss: 0.8554 - val_y1_output_root_mean_squared_error: 0.9329 - val_y2_output_loss: 2.9504 - val_y2_output_root_mean_squared_error: 1.6983
# Epoch 101/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5862 - y1_output_loss: 0.6946 - y1_output_root_mean_squared_error: 0.8285 - y2_output_loss: 1.8911 - y2_output_root_mean_squared_error: 1.3692 - val_loss: 3.3448 - val_y1_output_loss: 0.9859 - val_y1_output_root_mean_squared_error: 0.9957 - val_y2_output_loss: 2.3726 - val_y2_output_root_mean_squared_error: 1.5340
# Epoch 102/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1113 - y1_output_loss: 0.6614 - y1_output_root_mean_squared_error: 0.8089 - y2_output_loss: 2.4492 - y2_output_root_mean_squared_error: 1.5531 - val_loss: 2.5449 - val_y1_output_loss: 0.7819 - val_y1_output_root_mean_squared_error: 0.8840 - val_y2_output_loss: 1.7695 - val_y2_output_root_mean_squared_error: 1.3279
# Epoch 103/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7230 - y1_output_loss: 0.5676 - y1_output_root_mean_squared_error: 0.7524 - y2_output_loss: 2.1561 - y2_output_root_mean_squared_error: 1.4633 - val_loss: 4.3648 - val_y1_output_loss: 0.8969 - val_y1_output_root_mean_squared_error: 0.9577 - val_y2_output_loss: 3.5891 - val_y2_output_root_mean_squared_error: 1.8568
# Epoch 104/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7008 - y1_output_loss: 0.7143 - y1_output_root_mean_squared_error: 0.8381 - y2_output_loss: 1.9860 - y2_output_root_mean_squared_error: 1.4006 - val_loss: 2.5020 - val_y1_output_loss: 0.6836 - val_y1_output_root_mean_squared_error: 0.8283 - val_y2_output_loss: 1.8531 - val_y2_output_root_mean_squared_error: 1.3475
# Epoch 105/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1301 - y1_output_loss: 0.4800 - y1_output_root_mean_squared_error: 0.6923 - y2_output_loss: 1.6498 - y2_output_root_mean_squared_error: 1.2800 - val_loss: 2.6092 - val_y1_output_loss: 0.8470 - val_y1_output_root_mean_squared_error: 0.9277 - val_y2_output_loss: 1.7981 - val_y2_output_root_mean_squared_error: 1.3224
# Epoch 106/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4641 - y1_output_loss: 0.6267 - y1_output_root_mean_squared_error: 0.7876 - y2_output_loss: 1.8427 - y2_output_root_mean_squared_error: 1.3499 - val_loss: 50.7760 - val_y1_output_loss: 17.2630 - val_y1_output_root_mean_squared_error: 4.1978 - val_y2_output_loss: 32.7097 - val_y2_output_root_mean_squared_error: 5.7580
# Epoch 107/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8990 - y1_output_loss: 2.4724 - y1_output_root_mean_squared_error: 1.4274 - y2_output_loss: 4.4275 - y2_output_root_mean_squared_error: 1.9609 - val_loss: 7.0654 - val_y1_output_loss: 1.4527 - val_y1_output_root_mean_squared_error: 1.2169 - val_y2_output_loss: 5.6907 - val_y2_output_root_mean_squared_error: 2.3631
# Epoch 108/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5335 - y1_output_loss: 0.5953 - y1_output_root_mean_squared_error: 0.7697 - y2_output_loss: 1.9376 - y2_output_root_mean_squared_error: 1.3876 - val_loss: 2.1664 - val_y1_output_loss: 0.6252 - val_y1_output_root_mean_squared_error: 0.7813 - val_y2_output_loss: 1.5811 - val_y2_output_root_mean_squared_error: 1.2473
# Epoch 109/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1730 - y1_output_loss: 0.5102 - y1_output_root_mean_squared_error: 0.7127 - y2_output_loss: 1.6630 - y2_output_root_mean_squared_error: 1.2863 - val_loss: 2.9745 - val_y1_output_loss: 0.5844 - val_y1_output_root_mean_squared_error: 0.7564 - val_y2_output_loss: 2.4539 - val_y2_output_root_mean_squared_error: 1.5500
# Epoch 110/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7781 - y1_output_loss: 0.3906 - y1_output_root_mean_squared_error: 0.6175 - y2_output_loss: 1.3896 - y2_output_root_mean_squared_error: 1.1709 - val_loss: 7.8667 - val_y1_output_loss: 3.1646 - val_y1_output_root_mean_squared_error: 1.8024 - val_y2_output_loss: 4.6430 - val_y2_output_root_mean_squared_error: 2.1490
# Epoch 111/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8850 - y1_output_loss: 1.5245 - y1_output_root_mean_squared_error: 1.2162 - y2_output_loss: 6.3599 - y2_output_root_mean_squared_error: 2.4426 - val_loss: 2.2343 - val_y1_output_loss: 0.6710 - val_y1_output_root_mean_squared_error: 0.8226 - val_y2_output_loss: 1.5856 - val_y2_output_root_mean_squared_error: 1.2481
# Epoch 112/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2282 - y1_output_loss: 0.5791 - y1_output_root_mean_squared_error: 0.7567 - y2_output_loss: 1.6509 - y2_output_root_mean_squared_error: 1.2807 - val_loss: 2.7501 - val_y1_output_loss: 0.7346 - val_y1_output_root_mean_squared_error: 0.8619 - val_y2_output_loss: 2.0989 - val_y2_output_root_mean_squared_error: 1.4168
# Epoch 113/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7762 - y1_output_loss: 0.6437 - y1_output_root_mean_squared_error: 0.7904 - y2_output_loss: 2.1319 - y2_output_root_mean_squared_error: 1.4493 - val_loss: 2.6200 - val_y1_output_loss: 0.9312 - val_y1_output_root_mean_squared_error: 0.9622 - val_y2_output_loss: 1.7431 - val_y2_output_root_mean_squared_error: 1.3016
# Epoch 114/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6896 - y1_output_loss: 0.6383 - y1_output_root_mean_squared_error: 0.7765 - y2_output_loss: 2.0515 - y2_output_root_mean_squared_error: 1.3975 - val_loss: 2.8504 - val_y1_output_loss: 1.0507 - val_y1_output_root_mean_squared_error: 1.0258 - val_y2_output_loss: 1.8668 - val_y2_output_root_mean_squared_error: 1.3409
# Epoch 115/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2401 - y1_output_loss: 0.5476 - y1_output_root_mean_squared_error: 0.7365 - y2_output_loss: 1.6930 - y2_output_root_mean_squared_error: 1.2997 - val_loss: 2.6684 - val_y1_output_loss: 0.8392 - val_y1_output_root_mean_squared_error: 0.9233 - val_y2_output_loss: 1.8937 - val_y2_output_root_mean_squared_error: 1.3475
# Epoch 116/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2893 - y1_output_loss: 0.6059 - y1_output_root_mean_squared_error: 0.7764 - y2_output_loss: 1.6829 - y2_output_root_mean_squared_error: 1.2913 - val_loss: 2.6175 - val_y1_output_loss: 0.6435 - val_y1_output_root_mean_squared_error: 0.8025 - val_y2_output_loss: 2.0029 - val_y2_output_root_mean_squared_error: 1.4048
# Epoch 117/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8100 - y1_output_loss: 0.4018 - y1_output_root_mean_squared_error: 0.6303 - y2_output_loss: 1.4081 - y2_output_root_mean_squared_error: 1.1817 - val_loss: 2.0173 - val_y1_output_loss: 0.5248 - val_y1_output_root_mean_squared_error: 0.7266 - val_y2_output_loss: 1.5470 - val_y2_output_root_mean_squared_error: 1.2203
# Epoch 118/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0478 - y1_output_loss: 0.4514 - y1_output_root_mean_squared_error: 0.6717 - y2_output_loss: 1.5958 - y2_output_root_mean_squared_error: 1.2594 - val_loss: 2.5776 - val_y1_output_loss: 0.6343 - val_y1_output_root_mean_squared_error: 0.7897 - val_y2_output_loss: 2.0068 - val_y2_output_root_mean_squared_error: 1.3978
# Epoch 119/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2593 - y1_output_loss: 0.4993 - y1_output_root_mean_squared_error: 0.7059 - y2_output_loss: 1.7593 - y2_output_root_mean_squared_error: 1.3223 - val_loss: 3.2264 - val_y1_output_loss: 0.7650 - val_y1_output_root_mean_squared_error: 0.8611 - val_y2_output_loss: 2.5505 - val_y2_output_root_mean_squared_error: 1.5764
# Epoch 120/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9282 - y1_output_loss: 0.7124 - y1_output_root_mean_squared_error: 0.8216 - y2_output_loss: 3.2148 - y2_output_root_mean_squared_error: 1.7753 - val_loss: 2.0472 - val_y1_output_loss: 0.5230 - val_y1_output_root_mean_squared_error: 0.7129 - val_y2_output_loss: 1.5562 - val_y2_output_root_mean_squared_error: 1.2406
# Epoch 121/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0050 - y1_output_loss: 0.4732 - y1_output_root_mean_squared_error: 0.6853 - y2_output_loss: 1.5323 - y2_output_root_mean_squared_error: 1.2314 - val_loss: 3.8071 - val_y1_output_loss: 0.9457 - val_y1_output_root_mean_squared_error: 0.9673 - val_y2_output_loss: 2.8615 - val_y2_output_root_mean_squared_error: 1.6946
# Epoch 122/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7577 - y1_output_loss: 0.4187 - y1_output_root_mean_squared_error: 0.6459 - y2_output_loss: 1.3389 - y2_output_root_mean_squared_error: 1.1542 - val_loss: 2.0644 - val_y1_output_loss: 0.6099 - val_y1_output_root_mean_squared_error: 0.7736 - val_y2_output_loss: 1.4691 - val_y2_output_root_mean_squared_error: 1.2108
# Epoch 123/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3191 - y1_output_loss: 0.4650 - y1_output_root_mean_squared_error: 0.6805 - y2_output_loss: 1.8540 - y2_output_root_mean_squared_error: 1.3506 - val_loss: 3.2008 - val_y1_output_loss: 0.6433 - val_y1_output_root_mean_squared_error: 0.7864 - val_y2_output_loss: 2.6107 - val_y2_output_root_mean_squared_error: 1.6070
# Epoch 124/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7845 - y1_output_loss: 0.3757 - y1_output_root_mean_squared_error: 0.6106 - y2_output_loss: 1.4084 - y2_output_root_mean_squared_error: 1.1843 - val_loss: 2.2662 - val_y1_output_loss: 0.6097 - val_y1_output_root_mean_squared_error: 0.7757 - val_y2_output_loss: 1.6795 - val_y2_output_root_mean_squared_error: 1.2901
# Epoch 125/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9723 - y1_output_loss: 0.3636 - y1_output_root_mean_squared_error: 0.6009 - y2_output_loss: 1.6090 - y2_output_root_mean_squared_error: 1.2606 - val_loss: 2.1438 - val_y1_output_loss: 0.5633 - val_y1_output_root_mean_squared_error: 0.7419 - val_y2_output_loss: 1.6228 - val_y2_output_root_mean_squared_error: 1.2623
# Epoch 126/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9712 - y1_output_loss: 0.4292 - y1_output_root_mean_squared_error: 0.6543 - y2_output_loss: 1.5414 - y2_output_root_mean_squared_error: 1.2376 - val_loss: 1.8447 - val_y1_output_loss: 0.4800 - val_y1_output_root_mean_squared_error: 0.6901 - val_y2_output_loss: 1.4187 - val_y2_output_root_mean_squared_error: 1.1698
# Epoch 127/500
# ...
# Epoch 459/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5523 - y1_output_loss: 0.1497 - y1_output_root_mean_squared_error: 0.3856 - y2_output_loss: 0.4025 - y2_output_root_mean_squared_error: 0.6284 - val_loss: 0.9582 - val_y1_output_loss: 0.1938 - val_y1_output_root_mean_squared_error: 0.4442 - val_y2_output_loss: 0.7909 - val_y2_output_root_mean_squared_error: 0.8722
# Epoch 460/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4002 - y1_output_loss: 0.1329 - y1_output_root_mean_squared_error: 0.3632 - y2_output_loss: 0.2674 - y2_output_root_mean_squared_error: 0.5148 - val_loss: 1.2556 - val_y1_output_loss: 0.3296 - val_y1_output_root_mean_squared_error: 0.5817 - val_y2_output_loss: 0.9394 - val_y2_output_root_mean_squared_error: 0.9578
# Epoch 461/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4044 - y1_output_loss: 0.1319 - y1_output_root_mean_squared_error: 0.3630 - y2_output_loss: 0.2725 - y2_output_root_mean_squared_error: 0.5183 - val_loss: 1.4111 - val_y1_output_loss: 0.2277 - val_y1_output_root_mean_squared_error: 0.4802 - val_y2_output_loss: 1.1962 - val_y2_output_root_mean_squared_error: 1.0865
# Epoch 462/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7517 - y1_output_loss: 0.1995 - y1_output_root_mean_squared_error: 0.4428 - y2_output_loss: 0.5521 - y2_output_root_mean_squared_error: 0.7344 - val_loss: 1.7269 - val_y1_output_loss: 0.3451 - val_y1_output_root_mean_squared_error: 0.5876 - val_y2_output_loss: 1.3528 - val_y2_output_root_mean_squared_error: 1.1754
# Epoch 463/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4015 - y1_output_loss: 0.1209 - y1_output_root_mean_squared_error: 0.3469 - y2_output_loss: 0.2807 - y2_output_root_mean_squared_error: 0.5269 - val_loss: 1.5125 - val_y1_output_loss: 0.3733 - val_y1_output_root_mean_squared_error: 0.6051 - val_y2_output_loss: 1.1200 - val_y2_output_root_mean_squared_error: 1.0707
# Epoch 464/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4360 - y1_output_loss: 0.1101 - y1_output_root_mean_squared_error: 0.3312 - y2_output_loss: 0.3258 - y2_output_root_mean_squared_error: 0.5676 - val_loss: 0.9787 - val_y1_output_loss: 0.1938 - val_y1_output_root_mean_squared_error: 0.4437 - val_y2_output_loss: 0.8186 - val_y2_output_root_mean_squared_error: 0.8842
# Epoch 465/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3323 - y1_output_loss: 0.1466 - y1_output_root_mean_squared_error: 0.3814 - y2_output_loss: 0.1856 - y2_output_root_mean_squared_error: 0.4242 - val_loss: 0.9940 - val_y1_output_loss: 0.1897 - val_y1_output_root_mean_squared_error: 0.4349 - val_y2_output_loss: 0.8059 - val_y2_output_root_mean_squared_error: 0.8971
# Epoch 466/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2774 - y1_output_loss: 0.1015 - y1_output_root_mean_squared_error: 0.3179 - y2_output_loss: 0.1760 - y2_output_root_mean_squared_error: 0.4187 - val_loss: 1.2293 - val_y1_output_loss: 0.2114 - val_y1_output_root_mean_squared_error: 0.4599 - val_y2_output_loss: 1.0025 - val_y2_output_root_mean_squared_error: 1.0088
# Epoch 467/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2904 - y1_output_loss: 0.0887 - y1_output_root_mean_squared_error: 0.2974 - y2_output_loss: 0.2016 - y2_output_root_mean_squared_error: 0.4441 - val_loss: 1.7708 - val_y1_output_loss: 0.3882 - val_y1_output_root_mean_squared_error: 0.6142 - val_y2_output_loss: 1.3778 - val_y2_output_root_mean_squared_error: 1.1805
# Epoch 468/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4058 - y1_output_loss: 0.1039 - y1_output_root_mean_squared_error: 0.3208 - y2_output_loss: 0.3019 - y2_output_root_mean_squared_error: 0.5460 - val_loss: 1.3458 - val_y1_output_loss: 0.2895 - val_y1_output_root_mean_squared_error: 0.5396 - val_y2_output_loss: 1.0702 - val_y2_output_root_mean_squared_error: 1.0269
# Epoch 469/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3422 - y1_output_loss: 0.1362 - y1_output_root_mean_squared_error: 0.3683 - y2_output_loss: 0.2060 - y2_output_root_mean_squared_error: 0.4509 - val_loss: 1.2022 - val_y1_output_loss: 0.2541 - val_y1_output_root_mean_squared_error: 0.5076 - val_y2_output_loss: 0.9334 - val_y2_output_root_mean_squared_error: 0.9718
# Epoch 470/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3191 - y1_output_loss: 0.1071 - y1_output_root_mean_squared_error: 0.3266 - y2_output_loss: 0.2124 - y2_output_root_mean_squared_error: 0.4601 - val_loss: 2.0401 - val_y1_output_loss: 0.3301 - val_y1_output_root_mean_squared_error: 0.5841 - val_y2_output_loss: 1.7821 - val_y2_output_root_mean_squared_error: 1.3034
# Epoch 471/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4057 - y1_output_loss: 0.1295 - y1_output_root_mean_squared_error: 0.3563 - y2_output_loss: 0.2761 - y2_output_root_mean_squared_error: 0.5184 - val_loss: 0.9820 - val_y1_output_loss: 0.2036 - val_y1_output_root_mean_squared_error: 0.4548 - val_y2_output_loss: 0.8104 - val_y2_output_root_mean_squared_error: 0.8804
# Epoch 472/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3104 - y1_output_loss: 0.0956 - y1_output_root_mean_squared_error: 0.3083 - y2_output_loss: 0.2149 - y2_output_root_mean_squared_error: 0.4630 - val_loss: 1.3286 - val_y1_output_loss: 0.3780 - val_y1_output_root_mean_squared_error: 0.6137 - val_y2_output_loss: 0.9473 - val_y2_output_root_mean_squared_error: 0.9757
# Epoch 473/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3945 - y1_output_loss: 0.1323 - y1_output_root_mean_squared_error: 0.3626 - y2_output_loss: 0.2621 - y2_output_root_mean_squared_error: 0.5076 - val_loss: 1.2657 - val_y1_output_loss: 0.3127 - val_y1_output_root_mean_squared_error: 0.5561 - val_y2_output_loss: 0.9369 - val_y2_output_root_mean_squared_error: 0.9780
# Epoch 474/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2873 - y1_output_loss: 0.1143 - y1_output_root_mean_squared_error: 0.3374 - y2_output_loss: 0.1731 - y2_output_root_mean_squared_error: 0.4135 - val_loss: 2.6457 - val_y1_output_loss: 0.9279 - val_y1_output_root_mean_squared_error: 0.9770 - val_y2_output_loss: 1.6805 - val_y2_output_root_mean_squared_error: 1.3004
# Epoch 475/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4341 - y1_output_loss: 0.1604 - y1_output_root_mean_squared_error: 0.3939 - y2_output_loss: 0.2736 - y2_output_root_mean_squared_error: 0.5173 - val_loss: 0.9156 - val_y1_output_loss: 0.1973 - val_y1_output_root_mean_squared_error: 0.4469 - val_y2_output_loss: 0.7252 - val_y2_output_root_mean_squared_error: 0.8461
# Epoch 476/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2381 - y1_output_loss: 0.0988 - y1_output_root_mean_squared_error: 0.3139 - y2_output_loss: 0.1394 - y2_output_root_mean_squared_error: 0.3718 - val_loss: 1.0756 - val_y1_output_loss: 0.2978 - val_y1_output_root_mean_squared_error: 0.5398 - val_y2_output_loss: 0.7680 - val_y2_output_root_mean_squared_error: 0.8856
# Epoch 477/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2540 - y1_output_loss: 0.1179 - y1_output_root_mean_squared_error: 0.3431 - y2_output_loss: 0.1361 - y2_output_root_mean_squared_error: 0.3677 - val_loss: 0.9890 - val_y1_output_loss: 0.1872 - val_y1_output_root_mean_squared_error: 0.4365 - val_y2_output_loss: 0.7933 - val_y2_output_root_mean_squared_error: 0.8936
# Epoch 478/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3211 - y1_output_loss: 0.0912 - y1_output_root_mean_squared_error: 0.3019 - y2_output_loss: 0.2298 - y2_output_root_mean_squared_error: 0.4765 - val_loss: 0.9343 - val_y1_output_loss: 0.2160 - val_y1_output_root_mean_squared_error: 0.4661 - val_y2_output_loss: 0.7221 - val_y2_output_root_mean_squared_error: 0.8468
# Epoch 479/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3568 - y1_output_loss: 0.1071 - y1_output_root_mean_squared_error: 0.3266 - y2_output_loss: 0.2497 - y2_output_root_mean_squared_error: 0.4979 - val_loss: 1.0491 - val_y1_output_loss: 0.1958 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_loss: 0.8399 - val_y2_output_root_mean_squared_error: 0.9226
# Epoch 480/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3243 - y1_output_loss: 0.1151 - y1_output_root_mean_squared_error: 0.3388 - y2_output_loss: 0.2092 - y2_output_root_mean_squared_error: 0.4541 - val_loss: 1.5391 - val_y1_output_loss: 0.4337 - val_y1_output_root_mean_squared_error: 0.6514 - val_y2_output_loss: 1.0858 - val_y2_output_root_mean_squared_error: 1.0558
# Epoch 481/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3399 - y1_output_loss: 0.1193 - y1_output_root_mean_squared_error: 0.3440 - y2_output_loss: 0.2206 - y2_output_root_mean_squared_error: 0.4661 - val_loss: 0.8663 - val_y1_output_loss: 0.2026 - val_y1_output_root_mean_squared_error: 0.4558 - val_y2_output_loss: 0.6713 - val_y2_output_root_mean_squared_error: 0.8115
# Epoch 482/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3305 - y1_output_loss: 0.1106 - y1_output_root_mean_squared_error: 0.3317 - y2_output_loss: 0.2199 - y2_output_root_mean_squared_error: 0.4680 - val_loss: 1.3542 - val_y1_output_loss: 0.3578 - val_y1_output_root_mean_squared_error: 0.6060 - val_y2_output_loss: 1.0122 - val_y2_output_root_mean_squared_error: 0.9935
# Epoch 483/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3033 - y1_output_loss: 0.1101 - y1_output_root_mean_squared_error: 0.3294 - y2_output_loss: 0.1931 - y2_output_root_mean_squared_error: 0.4384 - val_loss: 1.1964 - val_y1_output_loss: 0.2684 - val_y1_output_root_mean_squared_error: 0.5177 - val_y2_output_loss: 0.9120 - val_y2_output_root_mean_squared_error: 0.9635
# Epoch 484/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3779 - y1_output_loss: 0.1142 - y1_output_root_mean_squared_error: 0.3376 - y2_output_loss: 0.2638 - y2_output_root_mean_squared_error: 0.5111 - val_loss: 0.9673 - val_y1_output_loss: 0.2214 - val_y1_output_root_mean_squared_error: 0.4732 - val_y2_output_loss: 0.7595 - val_y2_output_root_mean_squared_error: 0.8622
# Epoch 485/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3164 - y1_output_loss: 0.1300 - y1_output_root_mean_squared_error: 0.3596 - y2_output_loss: 0.1865 - y2_output_root_mean_squared_error: 0.4310 - val_loss: 1.1404 - val_y1_output_loss: 0.2138 - val_y1_output_root_mean_squared_error: 0.4626 - val_y2_output_loss: 0.9252 - val_y2_output_root_mean_squared_error: 0.9625
# Epoch 486/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6275 - y1_output_loss: 0.1944 - y1_output_root_mean_squared_error: 0.4381 - y2_output_loss: 0.4329 - y2_output_root_mean_squared_error: 0.6399 - val_loss: 1.1260 - val_y1_output_loss: 0.2701 - val_y1_output_root_mean_squared_error: 0.5178 - val_y2_output_loss: 0.8416 - val_y2_output_root_mean_squared_error: 0.9262
# Epoch 487/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3719 - y1_output_loss: 0.1063 - y1_output_root_mean_squared_error: 0.3254 - y2_output_loss: 0.2656 - y2_output_root_mean_squared_error: 0.5132 - val_loss: 1.3580 - val_y1_output_loss: 0.2674 - val_y1_output_root_mean_squared_error: 0.5138 - val_y2_output_loss: 1.0780 - val_y2_output_root_mean_squared_error: 1.0460
# Epoch 488/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4555 - y1_output_loss: 0.1077 - y1_output_root_mean_squared_error: 0.3256 - y2_output_loss: 0.3478 - y2_output_root_mean_squared_error: 0.5886 - val_loss: 1.2701 - val_y1_output_loss: 0.2538 - val_y1_output_root_mean_squared_error: 0.5053 - val_y2_output_loss: 0.9947 - val_y2_output_root_mean_squared_error: 1.0074
# Epoch 489/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2960 - y1_output_loss: 0.0982 - y1_output_root_mean_squared_error: 0.3120 - y2_output_loss: 0.1977 - y2_output_root_mean_squared_error: 0.4444 - val_loss: 1.0264 - val_y1_output_loss: 0.2731 - val_y1_output_root_mean_squared_error: 0.5213 - val_y2_output_loss: 0.7707 - val_y2_output_root_mean_squared_error: 0.8687
# Epoch 490/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3781 - y1_output_loss: 0.1227 - y1_output_root_mean_squared_error: 0.3494 - y2_output_loss: 0.2554 - y2_output_root_mean_squared_error: 0.5011 - val_loss: 1.2733 - val_y1_output_loss: 0.3416 - val_y1_output_root_mean_squared_error: 0.5805 - val_y2_output_loss: 0.9511 - val_y2_output_root_mean_squared_error: 0.9676
# Epoch 491/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3132 - y1_output_loss: 0.0975 - y1_output_root_mean_squared_error: 0.3119 - y2_output_loss: 0.2158 - y2_output_root_mean_squared_error: 0.4639 - val_loss: 0.9821 - val_y1_output_loss: 0.2449 - val_y1_output_root_mean_squared_error: 0.5005 - val_y2_output_loss: 0.7606 - val_y2_output_root_mean_squared_error: 0.8554
# Epoch 492/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3324 - y1_output_loss: 0.0993 - y1_output_root_mean_squared_error: 0.3148 - y2_output_loss: 0.2330 - y2_output_root_mean_squared_error: 0.4821 - val_loss: 1.2432 - val_y1_output_loss: 0.2239 - val_y1_output_root_mean_squared_error: 0.4748 - val_y2_output_loss: 1.0284 - val_y2_output_root_mean_squared_error: 1.0088
# Epoch 493/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5207 - y1_output_loss: 0.1271 - y1_output_root_mean_squared_error: 0.3560 - y2_output_loss: 0.3936 - y2_output_root_mean_squared_error: 0.6193 - val_loss: 0.8891 - val_y1_output_loss: 0.2157 - val_y1_output_root_mean_squared_error: 0.4693 - val_y2_output_loss: 0.6850 - val_y2_output_root_mean_squared_error: 0.8179
# Epoch 494/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3278 - y1_output_loss: 0.1130 - y1_output_root_mean_squared_error: 0.3346 - y2_output_loss: 0.2148 - y2_output_root_mean_squared_error: 0.4608 - val_loss: 1.0283 - val_y1_output_loss: 0.2016 - val_y1_output_root_mean_squared_error: 0.4519 - val_y2_output_loss: 0.8209 - val_y2_output_root_mean_squared_error: 0.9078
# Epoch 495/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2880 - y1_output_loss: 0.0934 - y1_output_root_mean_squared_error: 0.3049 - y2_output_loss: 0.1947 - y2_output_root_mean_squared_error: 0.4394 - val_loss: 1.3591 - val_y1_output_loss: 0.2269 - val_y1_output_root_mean_squared_error: 0.4765 - val_y2_output_loss: 1.1106 - val_y2_output_root_mean_squared_error: 1.0640
# Epoch 496/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4497 - y1_output_loss: 0.0969 - y1_output_root_mean_squared_error: 0.3108 - y2_output_loss: 0.3528 - y2_output_root_mean_squared_error: 0.5745 - val_loss: 1.0806 - val_y1_output_loss: 0.2558 - val_y1_output_root_mean_squared_error: 0.5067 - val_y2_output_loss: 0.8109 - val_y2_output_root_mean_squared_error: 0.9077
# Epoch 497/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2883 - y1_output_loss: 0.1063 - y1_output_root_mean_squared_error: 0.3248 - y2_output_loss: 0.1821 - y2_output_root_mean_squared_error: 0.4250 - val_loss: 1.5978 - val_y1_output_loss: 0.3243 - val_y1_output_root_mean_squared_error: 0.5640 - val_y2_output_loss: 1.2627 - val_y2_output_root_mean_squared_error: 1.1312
# Epoch 498/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3788 - y1_output_loss: 0.1275 - y1_output_root_mean_squared_error: 0.3559 - y2_output_loss: 0.2513 - y2_output_root_mean_squared_error: 0.4981 - val_loss: 1.0270 - val_y1_output_loss: 0.2067 - val_y1_output_root_mean_squared_error: 0.4584 - val_y2_output_loss: 0.8396 - val_y2_output_root_mean_squared_error: 0.9038
# Epoch 499/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3697 - y1_output_loss: 0.1157 - y1_output_root_mean_squared_error: 0.3372 - y2_output_loss: 0.2540 - y2_output_root_mean_squared_error: 0.5007 - val_loss: 0.9144 - val_y1_output_loss: 0.2092 - val_y1_output_root_mean_squared_error: 0.4546 - val_y2_output_loss: 0.7018 - val_y2_output_root_mean_squared_error: 0.8413
# Epoch 500/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3095 - y1_output_loss: 0.1023 - y1_output_root_mean_squared_error: 0.3185 - y2_output_loss: 0.2070 - y2_output_root_mean_squared_error: 0.4539 - val_loss: 0.8938 - val_y1_output_loss: 0.1912 - val_y1_output_root_mean_squared_error: 0.4396 - val_y2_output_loss: 0.6935 - val_y2_output_root_mean_squared_error: 0.8370

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9630 - y1_output_loss: 0.2408 - y1_output_root_mean_squared_error: 0.4869 - y2_output_loss: 0.7197 - y2_output_root_mean_squared_error: 0.8476
# Loss = 0.8938452005386353, Y1_loss = 0.19280044734477997, Y1_mse = 0.4395979642868042, Y2_loss = 0.693504273891449, Y2_mse = 0.8370177745819092

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
